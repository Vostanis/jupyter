# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import zipfile2
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

import fetch as f # local file

START_DATE = "2019-01-01"

big_7 = ["NVDA", "TSLA", "GOOG", "MSFT", "META", "AMZN", "AAPL"]
portfolio = ["NVDA", "GCT", "RYAAY"]
crypto3 = ["BTC-USD","ETH-USD","SOL-USD"]

big7_price = yf.download(big_7, start = START_DATE, interval = "1wk", group_by = "tickers") # big 7 pric history
portfolio_price = yf.download(portfolio, start = START_DATE, interval = "1wk", group_by = "tickers") # portfolio price history
crypto3_price = yf.download(crypto3, start = START_DATE, interval = "1d", group_by = "tickers")

big7_fin = f.bulkfin(big_7).reset_index() # big 7 financial statements (quarterly)
portfolio_fin = f.bulkfin(portfolio).reset_index() # portfolio financial statements (quarterly)
# Out:
# [*********************100%%**********************]  7 of 7 completed
# [*********************100%%**********************]  3 of 3 completed
# [*********************100%%**********************]  3 of 3 completed

# %%
ticker = "GCT"

tkr = yf.Ticker(ticker)
df = f.financials(ticker)
df['Earnings %'] = df['Net Income']/df['Total Revenue']

# print weekly candlesticks for last 3 years
hist = tkr.history(period="3y", interval="1d").reset_index()
fig = go.Figure(data=[go.Candlestick(x=hist['Date'],
                open=hist['Open'],
                high=hist['High'],
                low=hist['Low'],
                close=hist['Close'])])
fig.update_layout(title=f'{ticker}')
fig.show()

# Revenue & Earnings
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df["Total Revenue"], 
                            fill='tonexty',
                            mode="lines+markers",
                            line_color="rgb(38,70,83)",
                            name="Revenue"))
# fig_de.add_trace(go.Scatter(x=df["Date"], y=df["Gross Profit"], 
#                             fill='tozeroy',
#                             mode="lines+markers",
#                             name="Gross Profit"))
fig.add_trace(go.Scatter(x=df["Date"], y=df["Net Income"], 
                            fill='tozeroy',
                            mode="lines+markers",
                            line_color="rgb(52,194,177)",
                            name="Earnings")) # ADD EARNINGS % TO LABELS
# fig_de.add_trace(go.Scatter(x=df["Date"], y=df["Total Operating Income As Reported"], 
#                             fill='tozeroy',
#                             mode="lines+markers",
#                             name="Operating Income"))
fig.update_traces(marker_colorscale="Earth", selector=dict(type='scatter'))
fig.update_layout(title="Revenue & Earnings")
fig.show()

# Earnings %
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df["Earnings %"]*100,
                            mode="lines+markers",
                            line_color="rgb(38,70,83)",
                            name="Revenue"))
fig.update_traces(marker_colorscale="Earth", selector=dict(type='scatter'))
fig.update_layout(title="Earnings %")
fig.show()


# EPS
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df["Diluted EPS"],
                            mode="lines+markers",
                            line_color="rgb(38,70,83)",
                            name="Equity"))
fig.update_layout(title="Earnings Per Share (EPS)")
fig.show()

# Debt:Equity
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df["Total Equity Gross Minority Interest"], 
                            fill='tonexty',
                            mode="lines+markers",
                            line_color="rgb(38,70,83)",
                            name="Equity")) # fill to trace0 y
fig.add_trace(go.Scatter(x=df["Date"], y=df["Total Debt"], 
                            fill='tozeroy',
                            mode="lines+markers",
                            line_color="rgb(201,26,20)",
                            name="Debt")) # fill down to xaxis
fig.update_layout(title="Debt & Equity")
fig.show()

# dividens
df = tkr.dividends.reset_index()
pd.to_datetime(df["Date"])
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df["Dividends"],
                        mode="lines+markers"))
fig.update_layout(title="Dividends")
fig.show()

# ownership
df = tkr.major_holders
# df = df[0:3]
# df = df.rename(columns={0:"%", 1:"Owner"})
# fig_holders = px.bar(df, color="Owner", x="%", title="Ownership", orientation='h')
# fig_holders.show()
print(df)
print("Institutional Holders")
print(tkr.institutional_holders)
print("Mutual Fund Holders")
print(tkr.mutualfund_holders)
# Out:
#         0                                      1
# 0   8.11%        % of Shares Held by All Insider
# 1  27.37%       % of Shares Held by Institutions
# 2  29.79%        % of Float Held by Institutions
# 3      54  Number of Institutions Holding Shares
# Institutional Holders
#                                      Holder   Shares Date Reported   % Out  \
# 0             Acadian Asset Management. LLC  1096949    2023-09-29  0.0268
# 1                             Man Group PLC   276767    2023-09-29  0.0068
# 2     New York State Common Retirement Fund   215066    2023-12-30  0.0053
# 3             Renaissance Technologies, LLC   103500    2023-09-29  0.0025
# 4       Pacific Ridge Capital Partners, LLC    66568    2023-09-29  0.0016
# 5   State of Tennessee, Treasury Department    60941    2023-09-29  0.0015
# 6                 Millennium Management Llc    48691    2023-09-29  0.0012
# 7  Arrowstreet Capital, Limited Partnership    46534    2023-09-29  0.0011
# 8                 Two Sigma Investments, LP    45060    2023-09-29  0.0011
# 9                             Xtx Topco Ltd    40005    2023-09-29  0.0010
#
#       Value
# 0  30593798
# 1   7719004
# 2   5998169
# 3   2886604
# 4   1856574
# 5   1699638
# 6   1357987
# 7   1297828
# 8   1256718
# 9   1115735
# Mutual Fund Holders
#                                               Holder  Shares Date Reported  \
# 0                              Virtus Small Cap Fund   20737    2023-09-29
# 1               Fidelity NASDAQ Composite Index Fund   20832    2023-12-30
# 2  SEI Institutional Investment Tr-World Equity E...   17909    2023-11-29
# 3                  Voya International Small Cap Fund    8065    2023-10-30
# 4                Optimum Funds Tr-International Fund    2580    2023-09-29
# 5  SEI Institutional International Tr-Internation...    2091    2023-11-29
# 6                     Nationwide Multi Cap Portfolio      34    2023-10-30
#
#     % Out   Value
# 0  0.0005  578352
# 1  0.0005  581002
# 2  0.0004  499480
# 3  0.0002  224932
# 4  0.0001   71955
# 5  0.0001   58317
# 6  0.0000     948

# %%
ticker = "TSLA"
tkr = yf.Ticker(ticker)
hist = tkr.history(period="3y", interval="1wk").reset_index()
hist
# Out:
#                          Date        Open        High         Low       Close  \
# 0   2021-02-08 00:00:00-05:00  289.890015  292.589996  261.776672  272.040009
# 1   2021-02-15 00:00:00-05:00  272.666656  273.666656  254.003326  260.433319
# 2   2021-02-22 00:00:00-05:00  254.213333  256.166656  206.333328  225.166672
# 3   2021-03-01 00:00:00-05:00  230.036667  240.369995  179.830002  199.316666
# 4   2021-03-08 00:00:00-05:00  200.183334  239.283340  186.263336  231.243332
# ..                        ...         ...         ...         ...         ...
# 152 2024-01-08 00:00:00-05:00  236.139999  241.250000  217.149994  218.889999
# 153 2024-01-15 00:00:00-05:00  215.100006  223.490005  207.559998  212.190002
# 154 2024-01-22 00:00:00-05:00  212.259995  217.800003  180.059998  183.250000
# 155 2024-01-29 00:00:00-05:00  185.630005  196.360001  182.000000  187.910004
# 156 2024-02-05 00:00:00-05:00  184.259995  191.617096  175.009995  189.660004
#
#         Volume  Dividends  Stock Splits
# 0    350779800        0.0           0.0
# 1    248142600        0.0           0.0
# 2    662270100        0.0           0.0
# 3    709177200        0.0           0.0
# 4    749261100        0.0           0.0
# ..         ...        ...           ...
# 152  502263400        0.0           0.0
# 153  429210600        0.0           0.0
# 154  653348300        0.0           0.0
# 155  540565200        0.0           0.0
# 156  445246707        0.0           0.0
#
# [157 rows x 8 columns]

# %%
# crypto3_price

# %%
# btc = yf.Ticker("BTC-USD")
# btc = pd.DataFrame(btc)
# btc.reset_index()

# %%
ticker = "NVDA"

df = f.financials(ticker)
# df = df.columns

for column in df.columns:
    if "Cash" in column:
        print(column)
# Out:
# Cash Cash Equivalents And Short Term Investments
# Cash And Cash Equivalents
# Free Cash Flow
# End Cash Position
# Beginning Cash Position
# Changes In Cash
# Financing Cash Flow
# Cash Flow From Continuing Financing Activities
# Cash Dividends Paid
# Investing Cash Flow
# Cash Flow From Continuing Investing Activities
# Operating Cash Flow
# Cash Flow From Continuing Operating Activities
# Other Non Cash Items
